# %% [markdown]
# # **Image Classification of Omnivores and Herbivores using the CIFAR-100 Dataset**
#
# This project aims to classify images into two categories: omnivores and herbivores, utilizing the CIFAR-100 dataset. The CIFAR-100 dataset contains 60,000 32x32 color images in 100 classes, with each class containing 600 images. Here, we focus on distinguishing between animals that primarily consume plants (herbivores) and those that consume both plants and animals (omnivores). Through deep learning techniques and convolutional neural networks (CNNs), we seek to build a model capable of accurate classification among diverse species.

# %% [markdown]
# ## **Import modules**

# %%
import tensorflow as tf
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dropout, Flatten, Dense, BatchNormalization
from tensorflow.keras.utils import to_categorical
from tensorflow.keras import layers
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd

# %% [markdown]
# ## **Import the dataset**

# %%
(X_coarse_train, y_coarse_train), (X_coarse_test, y_coarse_test) = tf.keras.datasets.cifar100.load_data(
    label_mode='coarse'
)

(X_fine_train, y_fine_train), (X_fine_test, y_fine_test) = tf.keras.datasets.cifar100.load_data(
    label_mode='fine'
)
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-100-python.tar.gz
# 169001437/169001437 [==============================] - 4s 0us/step

# %% [markdown]
# ## **Data Preprocessing**
# We will be extracting only the `large omnivores and herbivores` coarse class from the dataset along with their fine classes.

# %%
# Extracting images from coarse dataset

coarse_train_index = (y_coarse_train == 11).reshape(X_coarse_train.shape[0]) # Returns the indices where y_coarse_train == 11
X_train = X_coarse_train[coarse_train_index] # Extracts the images from X_train with indices that match the class

coarse_test_index = (y_coarse_test == 11).reshape(X_coarse_test.shape[0])
X_test = X_coarse_test[coarse_test_index]

# %%
# Extracting index of fine labels

labels_of_herbi_omni = []
label_mapping = {}

str_labels = ['apple', 'aquarium_fish', 'baby', 'bear', 'beaver', 'bed', 'bee', 'beetle', 'bicycle', 'bottle', 'bowl', 'boy', 'bridge', 'bus', 'butterfly',
              'camel', 'can', 'castle', 'caterpillar', 'cattle', 'chair', 'chimpanzee', 'clock', 'cloud', 'cockroach', 'couch', 'crab', 'crocodile', 'cup', 'dinosaur',
              'dolphin', 'elephant', 'flatfish', 'forest', 'fox', 'girl', 'hamster', 'house', 'kangaroo', 'keyboard', 'lamp', 'lawn_mower', 'leopard', 'lion', 'lizard', 'lobster',
              'man', 'maple_tree', 'motorcycle', 'mountain', 'mouse', 'mushroom', 'oak_tree', 'orange', 'orchid', 'otter', 'palm_tree', 'pear', 'pickup_truck', 'pine_tree', 'plain',
              'plate', 'poppy', 'porcupine', 'possum', 'rabbit', 'raccoon', 'ray', 'road', 'rocket', 'rose', 'sea', 'seal', 'shark', 'shrew', 'skunk', 'skyscraper', 'snail',
              'snake', 'spider', 'squirrel', 'streetcar', 'sunflower', 'sweet_pepper', 'table', 'tank', 'telephone', 'television', 'tiger', 'tractor', 'train', 'trout',
              'tulip', 'turtle', 'wardrobe', 'whale', 'willow_tree', 'wolf', 'woman', 'worm']
herbi_omni = ['camel', 'cattle', 'chimpanzee', 'elephant', 'kangaroo']
print("Fine labels of Herbivores and Omnivores:")
for i, name in enumerate(str_labels):
  if name in herbi_omni:
    print(f"{i}: {name}")
    label_mapping[i] = herbi_omni.index(name)
    labels_of_herbi_omni.append(i)
# Out:
# Fine labels of Herbivores and Omnivores:
# 15: camel
# 19: cattle
# 21: chimpanzee
# 31: elephant
# 38: kangaroo

# %%
# Extracting fine labels of images from coarse indices

fine_train_index = np.isin(y_fine_train, labels_of_herbi_omni).reshape(X_fine_train.shape[0])
y_train = y_fine_train[fine_train_index]

fine_test_index = np.isin(y_fine_test, labels_of_herbi_omni).reshape(X_fine_test.shape[0])
y_test = y_fine_test[fine_test_index]

# %%
# Convert fine labels from their original numbers to arbitrary categorical numbers from 0 - 4

y_train = np.array([label_mapping[label[0]] for label in y_train]).reshape(-1, 1)
y_test = np.array([label_mapping[label[0]] for label in y_test]).reshape(-1, 1)

# Convert training and test labels to categorical variables. This does one-hot encoding

y_train = tf.keras.utils.to_categorical(y_train, num_classes=5)
y_test = tf.keras.utils.to_categorical(y_test, num_classes=5)

# %%
def count_samples():
  # Count samples per class in training set
  train_counts = {label: np.sum(np.argmax(y_train, axis=1) == label) for label in range(y_train.shape[1])}

  # Count samples per class in testing set
  test_counts = {label: np.sum(np.argmax(y_test, axis=1) == label) for label in range(y_test.shape[1])}

  print("\nNumber of samples per class in training set: ")
  for label, count in train_counts.items():
      print(f"{herbi_omni[label]} ({label}): {count}")

  print("\nNumber of samples per class in testing set: ")
  for label, count in test_counts.items():
      print(f"{herbi_omni[label]} ({label}): {count}")


  print(f"\nTotal number of training samples: {sum(train_counts.values())}")
  print(f"Total number of test samples: {sum(test_counts.values())}")

count_samples()
# Out:
# Number of samples per class in training set:
# camel (0): 500
# cattle (1): 500
# chimpanzee (2): 500
# elephant (3): 500
# kangaroo (4): 500
#
# Number of samples per class in testing set:
# camel (0): 100
# cattle (1): 100
# chimpanzee (2): 100
# elephant (3): 100
# kangaroo (4): 100
#
# Total number of training samples: 2500
# Total number of test samples: 500

# %%
# Normalize the pixels of the images from 0 to 1

X_train = X_train / 255
X_test = X_test / 255

# %%
# Display 25 sample images with labels
def view_samples():
  plt.figure(figsize=(10,10))
  for i in range(25):
      plt.subplot(5,5,i+1)
      plt.xticks([])
      plt.yticks([])
      plt.grid(False)
      plt.imshow(X_train[i], cmap=plt.cm.binary)
      plt.xlabel(herbi_omni[np.argmax(y_train[i])])
  plt.show()

view_samples()

# %% [markdown]
# ## **Data Augmentation**
# The dataset is too small for accurate image processing. According to Picsellia (2022), for a dataset to be adequate in size for image classification, around 1000 images per class is needed.

# %%
data_augmentation_pipeline = tf.keras.Sequential([
  layers.RandomFlip("horizontal_and_vertical"),
  layers.RandomRotation(0.2),
  tf.keras.layers.RandomZoom(0.3),
  tf.keras.layers.RandomContrast(0.3)
])

# Define the number of times to augment each image
num_augmentations = 2

# Initialize lists to store augmented images and labels
augmented_training_set = []
augmented_labels = []

# Apply data augmentation to each image multiple times
for image, label in zip(X_train, y_train):
    for _ in range(num_augmentations):
        augmented_image = data_augmentation_pipeline(image)  # Apply data augmentation
        augmented_training_set.append(augmented_image)
        augmented_labels.append(label)

augmented_training_set = np.array(augmented_training_set)
augmented_labels = np.array(augmented_labels)

# %%
augmented_training_set.shape
# Out:
# (5000, 32, 32, 3)

# %% [markdown]
# There are 5000 new images generated from the augmented training set. Below are some examples of the augmentations done.

# %%
plt.figure(figsize=(10,10))
for i in range(25):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(augmented_training_set[i], cmap=plt.cm.binary)
    plt.xlabel(herbi_omni[np.argmax(augmented_labels[i])])
plt.show()
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
# Merge original and augmented dataset, and shuffle to ensure randomness
X_train = np.concatenate((X_train, augmented_training_set), axis=0)
y_train = np.concatenate((y_train, augmented_labels), axis=0)

# Shuffle the merged dataset to maintain randomness
shuffle_indices = np.random.permutation(len(X_train))
X_train = X_train[shuffle_indices]
y_train = y_train[shuffle_indices]

view_samples()
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
# Count samples again to see how much the dataset increased by

count_samples()
# Out:
# Number of samples per class in training set:
# camel (0): 1500
# cattle (1): 1500
# chimpanzee (2): 1500
# elephant (3): 1500
# kangaroo (4): 1500
#
# Number of samples per class in testing set:
# camel (0): 100
# cattle (1): 100
# chimpanzee (2): 100
# elephant (3): 100
# kangaroo (4): 100
#
# Total number of training samples: 7500
# Total number of test samples: 500

# %% [markdown]
# We have now satisfied the minimum 1000 as cited earlier. We can now attempt training.

# %% [markdown]
# ## **Model Training**
# The neural network to be created is a Convolutional Neural Network (CNN). We will be making use of 3 layers of Convolution with Dropout layers in between. There will also be Batch Normalization layers in order to ensure that no weight during gradient descent will be far greater or lesser than others. This also speeds up the model.

# %%
from tensorflow.keras.callbacks import ModelCheckpoint
# Define the file path to save the model
filepath = 'highest_performing_model.h5'

# Define the ModelCheckpoint callback
checkpoint = ModelCheckpoint(filepath, monitor='val_accuracy', save_best_only=True, mode='max', verbose=1)

# Define the model architecture
model = tf.keras.Sequential([
    # CNN Layers
    layers.Conv2D(filters=16, kernel_size=(3, 3), activation='relu', input_shape=(32, 32, 3), padding='same'),
    layers.BatchNormalization(),
    layers.Conv2D(filters=16, kernel_size=(3, 3), activation='relu', padding='same'),
    layers.BatchNormalization(),
    layers.MaxPooling2D((3, 3)),
    layers.Dropout(0.25),

    layers.Conv2D(filters=32, kernel_size=(3, 3), activation='relu', input_shape=(32, 32, 3), padding='same'),
    layers.BatchNormalization(),
    layers.Conv2D(filters=32, kernel_size=(3, 3), activation='relu', padding='same'),
    layers.BatchNormalization(),
    layers.MaxPooling2D((3, 3)),
    layers.Dropout(0.25),

    layers.Conv2D(filters=64, kernel_size=(3, 3), activation='relu', padding='same'),
    layers.BatchNormalization(),
    layers.Conv2D(filters=64, kernel_size=(3, 3), activation='relu', padding='same'),
    layers.BatchNormalization(),
    layers.MaxPooling2D((3, 3)),
    layers.Dropout(0.25),

    layers.Conv2D(filters=128, kernel_size=(3, 3), activation='relu', padding='same'),
    layers.BatchNormalization(),
    layers.Conv2D(filters=128, kernel_size=(3, 3), activation='relu', padding='same'),
    layers.BatchNormalization(),
    layers.MaxPooling2D((3, 3)),
    layers.Dropout(0.25),

    layers.Conv2D(filters=256, kernel_size=(3, 3), activation='relu', padding='same'),
    layers.BatchNormalization(),
    layers.Conv2D(filters=256, kernel_size=(3, 3), activation='relu', padding='same'),
    layers.BatchNormalization(),
    layers.MaxPooling2D((3, 3)),
    layers.Dropout(0.25),

    # Hidden Layers / Connected Layers
    layers.Flatten(),
    layers.Dense(256, activation='relu'),
    layers.Dropout(0.5),
    layers.Dense(128, activation='relu'),
    layers.Dropout(0.5),
    layers.Dense(64, activation='relu'),
    layers.Dropout(0.5),
    layers.Dense(5, activation='softmax')
])


model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

model.fit(X_train, y_train, epochs=100, validation_data=(X_test[:1500], y_test[:1500]), callbacks=[checkpoint])
model.load_weights(filepath)
# Out:
# Traceback (most recent call last):
#
#   File ~\AppData\Roaming\Python\Python312\site-packages\IPython\core\interactiveshell.py:3553 in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   Cell In[1], line 1
#     from tensorflow.keras.callbacks import ModelCheckpoint
#
#   File c:\Users\notjo\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\__init__.py:24
#     from tensorflow.python import pywrap_tensorflow  # pylint: disable=unused-import
#
#   File c:\Users\notjo\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\python\__init__.py:49
#     from tensorflow.python import pywrap_tensorflow
#
#   File c:\Users\notjo\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\python\pywrap_tensorflow.py:58
#     from tensorflow.python.pywrap_tensorflow_internal import *
#
#   File c:\Users\notjo\AppData\Local\Programs\Python\Python312\Lib\site-packages\tensorflow\python\pywrap_tensorflow_internal.py:114
#     def TFE_ContextOptionsSetAsync(arg1, async):
#                                          ^
# SyntaxError: invalid syntax

# %%
import random

# Randomly select images from the test set
num_images = 500
random_indices = random.sample(range(len(X_test)), num_images)
random_images = X_test[random_indices]
random_labels = y_test[random_indices]

# Make predictions on the randomly selected images
random_predictions = model.predict(random_images)
random_predictions_labels = np.argmax(random_predictions, axis=1)

# Print the true labels and predicted labels
for i in range(num_images):
    true_label = np.argmax(random_labels[i])
    predicted_label = random_predictions_labels[i]
    print(f"Image {i+1}: True Label = {true_label}, Predicted Label = {predicted_label}")

# Calculate the percentage of correct predictions
correct_predictions = np.sum(random_predictions_labels == np.argmax(random_labels, axis=1))
accuracy = correct_predictions / num_images * 100
print(f"\nAccuracy: {accuracy}%")
# Out:
# 16/16 [==============================] - 1s 32ms/step
# Image 1: True Label = 1, Predicted Label = 1
# Image 2: True Label = 0, Predicted Label = 0
# Image 3: True Label = 2, Predicted Label = 2
# Image 4: True Label = 0, Predicted Label = 0
# Image 5: True Label = 2, Predicted Label = 2
# Image 6: True Label = 2, Predicted Label = 2
# Image 7: True Label = 2, Predicted Label = 2
# Image 8: True Label = 1, Predicted Label = 1
# Image 9: True Label = 0, Predicted Label = 3
# Image 10: True Label = 3, Predicted Label = 0
# Image 11: True Label = 4, Predicted Label = 4
# Image 12: True Label = 0, Predicted Label = 3
# Image 13: True Label = 0, Predicted Label = 3
# Image 14: True Label = 4, Predicted Label = 4
# Image 15: True Label = 4, Predicted Label = 4
# Image 16: True Label = 0, Predicted Label = 0
# Image 17: True Label = 2, Predicted Label = 2
# Image 18: True Label = 1, Predicted Label = 1
# Image 19: True Label = 4, Predicted Label = 1
# Image 20: True Label = 4, Predicted Label = 4
# Image 21: True Label = 0, Predicted Label = 0
# Image 22: True Label = 4, Predicted Label = 1
# Image 23: True Label = 0, Predicted Label = 1
# Image 24: True Label = 4, Predicted Label = 4
# Image 25: True Label = 4, Predicted Label = 4
# Image 26: True Label = 1, Predicted Label = 4
# Image 27: True Label = 2, Predicted Label = 2
# Image 28: True Label = 0, Predicted Label = 0
# Image 29: True Label = 0, Predicted Label = 0
# Image 30: True Label = 2, Predicted Label = 2
# Image 31: True Label = 1, Predicted Label = 1
# Image 32: True Label = 2, Predicted Label = 2
# Image 33: True Label = 3, Predicted Label = 4
# Image 34: True Label = 4, Predicted Label = 4
# Image 35: True Label = 2, Predicted Label = 2
# Image 36: True Label = 0, Predicted Label = 0
# Image 37: True Label = 0, Predicted Label = 0
# Image 38: True Label = 4, Predicted Label = 4
# Image 39: True Label = 1, Predicted Label = 1
# Image 40: True Label = 0, Predicted Label = 2
# Image 41: True Label = 4, Predicted Label = 4
# Image 42: True Label = 3, Predicted Label = 3
# Image 43: True Label = 0, Predicted Label = 3
# Image 44: True Label = 0, Predicted Label = 0
# Image 45: True Label = 0, Predicted Label = 0
# Image 46: True Label = 0, Predicted Label = 0
# Image 47: True Label = 2, Predicted Label = 2
# Image 48: True Label = 3, Predicted Label = 3
# Image 49: True Label = 0, Predicted Label = 1
# Image 50: True Label = 0, Predicted Label = 1
# Image 51: True Label = 1, Predicted Label = 0
# Image 52: True Label = 1, Predicted Label = 1
# Image 53: True Label = 2, Predicted Label = 2
# Image 54: True Label = 3, Predicted Label = 3
# Image 55: True Label = 0, Predicted Label = 0
# Image 56: True Label = 0, Predicted Label = 1
# Image 57: True Label = 1, Predicted Label = 1
# Image 58: True Label = 2, Predicted Label = 2
# Image 59: True Label = 2, Predicted Label = 2
# Image 60: True Label = 4, Predicted Label = 3
# Image 61: True Label = 2, Predicted Label = 2
# Image 62: True Label = 2, Predicted Label = 2
# Image 63: True Label = 2, Predicted Label = 2
# Image 64: True Label = 3, Predicted Label = 1
# Image 65: True Label = 0, Predicted Label = 4
# Image 66: True Label = 3, Predicted Label = 3
# Image 67: True Label = 1, Predicted Label = 1
# Image 68: True Label = 1, Predicted Label = 1
# Image 69: True Label = 4, Predicted Label = 1
# Image 70: True Label = 2, Predicted Label = 2
# Image 71: True Label = 1, Predicted Label = 2
# Image 72: True Label = 0, Predicted Label = 0
# Image 73: True Label = 3, Predicted Label = 3
# Image 74: True Label = 3, Predicted Label = 4
# Image 75: True Label = 3, Predicted Label = 3
# Image 76: True Label = 1, Predicted Label = 2
# Image 77: True Label = 2, Predicted Label = 2
# Image 78: True Label = 3, Predicted Label = 4
# Image 79: True Label = 2, Predicted Label = 2
# Image 80: True Label = 2, Predicted Label = 2
# Image 81: True Label = 4, Predicted Label = 4
# Image 82: True Label = 3, Predicted Label = 3
# Image 83: True Label = 4, Predicted Label = 4
# Image 84: True Label = 1, Predicted Label = 3
# Image 85: True Label = 0, Predicted Label = 0
# Image 86: True Label = 0, Predicted Label = 2
# Image 87: True Label = 2, Predicted Label = 2
# Image 88: True Label = 1, Predicted Label = 0
# Image 89: True Label = 3, Predicted Label = 2
# Image 90: True Label = 2, Predicted Label = 2
# Image 91: True Label = 1, Predicted Label = 1
# Image 92: True Label = 1, Predicted Label = 0
# Image 93: True Label = 3, Predicted Label = 3
# Image 94: True Label = 0, Predicted Label = 0
# Image 95: True Label = 0, Predicted Label = 4
# Image 96: True Label = 2, Predicted Label = 2
# Image 97: True Label = 1, Predicted Label = 1
# Image 98: True Label = 3, Predicted Label = 2
# Image 99: True Label = 1, Predicted Label = 3
# Image 100: True Label = 1, Predicted Label = 1
# Image 101: True Label = 1, Predicted Label = 1
# Image 102: True Label = 1, Predicted Label = 1
# Image 103: True Label = 0, Predicted Label = 0
# Image 104: True Label = 1, Predicted Label = 1
# Image 105: True Label = 4, Predicted Label = 4
# Image 106: True Label = 1, Predicted Label = 3
# Image 107: True Label = 2, Predicted Label = 2
# Image 108: True Label = 3, Predicted Label = 1
# Image 109: True Label = 1, Predicted Label = 1
# Image 110: True Label = 0, Predicted Label = 4
# Image 452: True Label = 4, Predicted Label = 1
# Image 453: True Label = 1, Predicted Label = 1
# Image 454: True Label = 3, Predicted Label = 3
# Image 455: True Label = 2, Predicted Label = 2
# Image 456: True Label = 2, Predicted Label = 2
# Image 457: True Label = 1, Predicted Label = 1
# Image 458: True Label = 4, Predicted Label = 4
# Image 459: True Label = 3, Predicted Label = 3
# Image 460: True Label = 0, Predicted Label = 1
# Image 461: True Label = 1, Predicted Label = 1
# Image 462: True Label = 3, Predicted Label = 0
# Image 463: True Label = 3, Predicted Label = 3
# Image 464: True Label = 1, Predicted Label = 1
# Image 465: True Label = 2, Predicted Label = 2
# Image 466: True Label = 3, Predicted Label = 3
# Image 467: True Label = 0, Predicted Label = 0
# Image 468: True Label = 4, Predicted Label = 4
# Image 469: True Label = 2, Predicted Label = 2
# Image 470: True Label = 1, Predicted Label = 0
# Image 471: True Label = 1, Predicted Label = 0
# Image 472: True Label = 4, Predicted Label = 4
# Image 473: True Label = 3, Predicted Label = 4
# Image 474: True Label = 1, Predicted Label = 1
# Image 475: True Label = 3, Predicted Label = 3
# Image 476: True Label = 4, Predicted Label = 1
# Image 477: True Label = 0, Predicted Label = 0
# Image 478: True Label = 3, Predicted Label = 3
# Image 479: True Label = 3, Predicted Label = 3
# Image 480: True Label = 0, Predicted Label = 0
# Image 481: True Label = 1, Predicted Label = 4
# Image 482: True Label = 3, Predicted Label = 3
# Image 483: True Label = 0, Predicted Label = 3
# Image 484: True Label = 3, Predicted Label = 3
# Image 485: True Label = 2, Predicted Label = 2
# Image 486: True Label = 3, Predicted Label = 3
# Image 487: True Label = 4, Predicted Label = 4
# Image 488: True Label = 1, Predicted Label = 1
# Image 489: True Label = 4, Predicted Label = 4
# Image 490: True Label = 2, Predicted Label = 2
# Image 491: True Label = 3, Predicted Label = 1
# Image 492: True Label = 2, Predicted Label = 2
# Image 493: True Label = 2, Predicted Label = 2
# Image 494: True Label = 4, Predicted Label = 0
# Image 495: True Label = 0, Predicted Label = 0
# Image 496: True Label = 1, Predicted Label = 1
# Image 497: True Label = 4, Predicted Label = 4
# Image 498: True Label = 4, Predicted Label = 0
# Image 499: True Label = 2, Predicted Label = 2
# Image 500: True Label = 3, Predicted Label = 3
#
# Accuracy: 70.6%

# %%
from sklearn.metrics import classification_report

# Make predictions on the test set
y_pred = model.predict(X_test)

# Convert predictions to class labels
y_pred_labels = np.argmax(y_pred, axis=1)
y_true_labels = np.argmax(y_test, axis=1)

# Generate the classification report
report = classification_report(y_true_labels, y_pred_labels)

# Print the report
print(report)
# Out:
# 16/16 [==============================] - 1s 32ms/step
#               precision    recall  f1-score   support
#
#            0       0.64      0.54      0.59       100
#            1       0.64      0.70      0.67       100
#            2       0.89      0.93      0.91       100
#            3       0.68      0.63      0.65       100
#            4       0.66      0.73      0.70       100
#
#     accuracy                           0.71       500
#    macro avg       0.70      0.71      0.70       500
# weighted avg       0.70      0.71      0.70       500

# %% [markdown]
# # Export the Model? Cge

# %%
import datetime
# Prompt the user for a file name
file_name = input("Enter a file name: ")

# Get the current date
current_date = datetime.datetime.now().strftime("%Y-%m-%d")

# Define the file path to save the model
model_path = f'{file_name}_{current_date}.h5'

# Save the model
model.save(model_path)

# Save the model weights
model.save_weights(f'{file_name}_{current_date}_weights.h5')
